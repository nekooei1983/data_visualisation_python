# %% [markdown]
# # This Iris project for calssification

# %% [markdown]
# ## Data exploration and Analysis
# We are importing:
# 1.   numpy: is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays.
# 2.   pandas: is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.
# 3.   seaborn: is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# 4. matplotlib: is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms. Matplotlib can be used in Python scripts, the Python and IPython shells, the Jupyter notebook, web application servers, and four graphical user interface toolkits.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 

sns.set(color_codes=True)
# %matplotlib inline

# %% [markdown]
# ### Input our dataset
#
# The heading is not right, we need to re-import it.

# %%
df = pd.read_csv('iris.data')

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# Re-impoting the dataset. It needs to understand the first row is actually is data and is not label.
#
# We can get help by ? mark

# %%
pd.read_csv?

# %%
df = pd.read_csv("iris.data",header = -1)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# We can also choose meaningful labels for each column

# %%
col_name = ['sepal length in cm', 'sepal width in cm', 'petal length in cm', 'petal width in cm', 'class' ]

# %%
df.columns = col_name
df.head()
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal width in cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa

# %% [markdown]
# ## We can import dataset (iris) directly from Seaborn\
# Iris database in very popular, so most libraries already have this dataset

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### we can do some data analysis
# we can see there is amost no difference between dataset for Seaborn and the dataset we imported

# %%
df.describe()
# Out:
#        sepal length in cm  sepal width in cm  petal length in cm  \
# count          150.000000         150.000000          150.000000
# mean             5.843333           3.054000            3.758667
# std              0.828066           0.433594            1.764420
# min              4.300000           2.000000            1.000000
# 25%              5.100000           2.800000            1.600000
# 50%              5.800000           3.000000            4.350000
# 75%              6.400000           3.300000            5.100000
# max              7.900000           4.400000            6.900000
#
#        petal width in cm
# count         150.000000
# mean            1.198667
# std             0.763161
# min             0.100000
# 25%             0.300000
# 50%             1.300000
# 75%             1.800000
# max             2.500000

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
# None

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal length in cm    150 non-null float64
# sepal width in cm     150 non-null float64
# petal length in cm    150 non-null float64
# petal width in cm     150 non-null float64
# class                 150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
# None

# %%
print(iris.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
print(df.groupby('class').size())
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# # This part is for Data visualisation

# %%
sns.pairplot(iris)

# %% [markdown]
# ### For categorical plot

# %%
sns.pairplot(iris, hue='species')

# %%
sns.pairplot(iris, hue='species', markers = ["o","s","D"])

# %%
sns.pairplot(iris, vars = ['sepal_length','sepal_width'])

# %%
sns.pairplot(iris, kind = "reg")

# %%
sns.pairplot(iris, kind = "reg", hue = 'species')

# %%
sns.pairplot(iris, hue = 'species', height =3)

# %%
sns.pairplot(iris, hue = 'species', height =3, aspect = 1)

# %%
iris.hist(edgecolor='black', linewidth=1.2, figsize = (12,8))
plt.show()

# %%
plt.subplot(2,2,1)
sns.violinplot(x='species',y='sepal_length', data = iris)
plt.subplot(2,2,2)
sns.violinplot(x='species',y='sepal_width', data = iris)
plt.subplot(2,2,3)
sns.violinplot(x='species',y='petal_length', data = iris)
plt.subplot(2,2,4)
sns.violinplot(x='species',y='petal_width', data = iris)

# %%
plt.figure(figsize= (12,8))
plt.subplot(2,2,1)
sns.violinplot(x='species',y='sepal_length', data = iris)
plt.subplot(2,2,2)
sns.violinplot(x='species',y='sepal_width', data = iris)
plt.subplot(2,2,3)
sns.violinplot(x='species',y='petal_length', data = iris)
plt.subplot(2,2,4)
sns.violinplot(x='species',y='petal_width', data = iris)

# %%
iris.boxplot(by='species', figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002CD9E2A1C88>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(iris, figsize=(12,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002CD8EB27128>,
# ...
#       dtype=object)
